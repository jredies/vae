# %%
import pandas as pd

# %%
pd.read_csv('../outputs/reg/output/anneal_start_100_end_200_type_linear.csv.csv').loc[300:, ['train_loss', 'val_loss']].rolling(8).mean().plot(subplots=True, figsize=(20, 10))
# Out:
# array([<Axes: >, <Axes: >], dtype=object)
